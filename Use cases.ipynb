# %% [markdown]
# ##Siva

# %%
# %sql

CREATE VOLUME IF NOT EXISTS workspace.default.volume;

# %%
# %py

import requests

api_url= "https://public.tableau.com/app/sample-data/mobile_os_usage.csv"

res = requests.get(api_url)

res_text = res.text

file_path_to_save = "/Volumes/workspace/default/volume/mobile_os_usage.csv"

dbutils.fs.put(file_path_to_save,res_text,overwrite=True)

# %%
# %run
"/Workspace/Users/sivagpm3817@gmail.com/SivaFile/"

# %%
# %sh
ls /Workspace

# %%
dbutils.fs.ls("/Volumes/workspace/default/volume/mobile_os_usage.csv")

# %%
# %py
df1=spark.read.csv("/Volumes/workspace/default/volume/mobile_os_usage.csv", header=True, inferSchema=True)
#display(df1)
#df1.show()

# %%
# %python

file_path = "/Volumes/workspace/default/volume/mobile_os_usage.csv"

df1 = spark.read.format("csv").option("header", "true").option("inferSchema", "true").load(file_path)
#df1.show()

# %%
# Clean column names by replacing spaces with underscores
df1_clean = df1.withColumnRenamed("Mobile Operating System", "mobile_operating_system") \
    .withColumnRenamed("Percent of Usage", "percent_of_usage")

df1_clean.show()

# %%
df1=spark.read.csv("/Volumes/workspace/default/volume/mobile_os_usage.csv")
df2=df1.write.saveAsTable("mobile_os_usage_table1")
#display(df2)

# %%
# %sql
select * from default.mobile_os_usage_table1 limit 1;

# %%
# %python
name="siva"
print(name.upper())

# %%
# %pip install pypi

# %%
# %py 
import pandas
#display(pandas.read_csv("/Volumes/workspace/default/volume/mobile_os_usage.csv"))

# %%
# %sh
echo "Magic commands tasks completed"
